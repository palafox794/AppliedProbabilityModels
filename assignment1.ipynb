# %%
R.version
# Out:
#                _
# platform       x86_64-apple-darwin17.0
# arch           x86_64
# os             darwin17.0
# system         x86_64, darwin17.0
# status
# major          4
# minor          0.0
# year           2020
# month          04
# day            24
# svn rev        78286
# language       R
# version.string R version 4.0.0 (2020-04-24)
# nickname       Arbor Day

# %% [markdown]
# ### Assignment # 1
# We will explore the use of Monterrey's city subway. Data is can be downloaded as a csv file at INEGI's site: https://www.inegi.org.mx/app/tabulados/?nc=100100049 . It shows the number of passengers per month (in thousands) from January 2018 to June 2020. To compare the same time periods, we will restrict our attention to the first six months of every year.

# %%
df <- read.csv(file = 'Tabulado-metrorrey.csv')

# %%
df
# Out:
#    Periodo
# 1  2018
# 2  Enero
# 3  Febrero
# 4  Marzo
# 5  Abril
# 6  Mayo
# 7  Junio
# 8  Julio
# 9  Agosto
# 10 Septiembre
# 11 Octubre
# 12 Noviembre
# 13 Diciembre
# 14 2019
# 15 Enero  P
# 16 Febrero
# 17 Marzo
# 18 Abril
# 19 Mayo
# 20 Junio
# 21 Julio
# 22 Agosto
# 23 Septiembre
# 24 Octubre
# 25 Noviembre
# 26 Diciembre
# 27 2020
# 28 Enero
# 29 Febrero
# 30 Marzo
# 31 Abril
# 32 Mayo
# 33 Junio
# 34 P Cifras preliminares a partir de la fecha en que se indica.     a Dato no acumulable. b Datos estimados por la fuente informante.Fecha de actualización: Martes
#    Longitud.en.servicio.....km...a Trenes.en.servicio..a
# 1                                  NA
# 2  32                              40
# 3  32                              40
# 4  32                              40
# 5  32                              40
# 6  32                              40
# 7  32                              40
# 8  32                              40
# 9  32                              40
# 10 32                              40
# 11 32                              40
# 12 32                              40
# 13 32                              40
# 14                                 NA
# 15 32                              40
# 16 32                              40
# 17 32                              40
# 18 32                              40
# 19 32                              40
# 20 32                              40
# 21 32                              40
# 22 32                              40
# 23 32                              40
# 24 32                              40
# 25 32                              40
# 26 32                              40
# 27                                 NA
# 28 32                              40
# 29 32                              40
# 30 32                              40
# 31 32                              40
# 32 32                              40
# 33 32                              40
# 34  11 de Agosto de 2020           NA
#    Kilómetros.recorridos.....Miles.de.kilómetros.
# 1       NA
# 2  837.346
# 3  750.995
# 4  811.256
# 5  816.056
# 6  842.884
# 7  814.062
# 8  841.440
# 9  830.254
# 10 831.225
# 11 844.341
# 12 799.260
# 13 827.839
# 14      NA
# 15 832.560
# 16 779.232
# 17 797.215
# 18 798.670
# 19 888.883
# 20 812.405
# 21 825.651
# 22 835.653
# 23 796.467
# 24 857.396
# 25 789.919
# 26 823.980
# 27      NA
# 28 836.754
# 29 785.805
# 30 813.971
# 31 663.616
# 32 663.410
# 33 737.213
# 34      NA
#    Pasajeros.transportados.....Miles.de.pasajeros.
# 1         NA
# 2  13529.975
# 3  14404.827
# 4  15102.947
# 5  14991.675
# 6  15999.968
# 7  14314.628
# 8  14527.242
# 9  16085.637
# 10 15259.985
# 11 16491.705
# 12 15597.934
# 13 14511.823
# 14        NA
# 15 14534.620
# 16 14511.121
# 17 14659.777
# 18 14826.921
# 19 16515.394
# 20 14750.238
# 21 15431.778
# 22 17067.167
# 23 15612.324
# 24 17534.523
# 25 16253.617
# 26 15097.727
# 27        NA
# 28 15220.380
# 29 15548.331
# 30 12554.885
# 31  5653.458
# 32  4933.483
# 33  7208.065
# 34        NA
#    Ingresos.por.pasaje.....Miles.de.pesos.
# 1        NA
# 2  33945.97
# 3  35350.89
# 4  37069.06
# 5  36218.61
# 6  39322.05
# 7  35505.47
# 8  36103.93
# 9  37601.06
# 10 36789.80
# 11 37727.26
# 12 38903.43
# 13 37035.07
# 14       NA
# 15 37788.65
# 16 38563.13
# 17 39856.49
# 18 36945.75
# 19 40709.65
# 20 34491.96
# 21 33845.95
# 22 41706.75
# 23 35305.79
# 24 42141.06
# 25 42777.08
# 26 40373.76
# 27       NA
# 28 40701.75
# 29 41284.20
# 30 33494.51
# 31 14374.49
# 32 11983.85
# 33 16926.22
# 34       NA
#    Energia.eléctrica.consumida.....Miles.de.KWH..b
# 1        NA
# 2  2999.103
# 3  2768.079
# 4  3081.705
# 5  2980.418
# 6  3212.043
# 7  3405.397
# 8  3569.510
# 9  3608.949
# 10 3222.118
# 11 3175.603
# 12 3074.549
# 13 3046.979
# 14       NA
# 15 2989.541
# 16 2751.011
# 17 2909.423
# 18 3015.587
# 19 3321.616
# 20 3521.244
# 21 3672.701
# 22 3726.196
# 23 3286.194
# 24 3349.742
# 25 3057.293
# 26 3099.605
# 27       NA
# 28 3206.312
# 29 2973.255
# 30 3148.530
# 31 2685.526
# 32 2586.921
# 33 3174.492
# 34       NA

# %% [markdown]
# The table has additional data which we will not use for now. So we extract the column ```Pasajeros Transportados ... miles de pasajeros``` which is Spanish for ```Passengers transported ... thousands of passengers```.
# Also, because of the table structure, there will be some NA in the column with the number of passengers, corresponding to the change of years. We will get rid of those and keep only the numerical data

# %%
passng = df$Pasajeros.transportados.....Miles.de.pasajeros.

# %%
passng = passng[!is.na(passng)]

# %% [markdown]
# We extrat the number of passengers for the first six months of each year, which correspond to the months 1 to 6, 13 to 18 and 25 to 30 from our list

# %%
passng2018 = passng[1:6]

# %%
passng2019 = passng[13:18]

# %%
passng2020 = passng[25:30]

# %% [markdown]
# Here is a summary of the data

# %%
summary(passng2018)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   13530   14337   14698   14724   15075   16000

# %%
summary(passng2019)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   14511   14566   14705   14966   14808   16515

# %%
summary(passng2020)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#    4933    6042    9881   10186   14554   15548

# %% [markdown]
# Since current year is anomalous due to SARS-Cov-2 pandemic, we show three boxplots: first, one for the years 2018-2019; next, a boxplot for 2020 alone; and finally, a boxplot for all of three years.

# %%
boxplot(passng2018, passng2019, names = c("2018", "2019"))
# Out:
# plot without title

# %%
boxplot(passng2020, names = c("2020"))
# Out:
# plot without title

# %%
boxplot(passng2018, passng2019, passng2020, names = c("2018", "2019", "2020"))
# Out:
# plot without title

# %% [markdown]
# --------------------------
#
# We will now show three violin plots, just as before: one with 2018 and 2019 data, one with 2020 data, and one with all the data.
# To plot the violin chart, we need the ```ggplot2``` library. Intuitively (at least from my understanding) the violin plot displays the same information as a boxplot, but instead of having a rectangle-shaped figure, you get an approximation of the density of the data.

# %%
library(ggplot2)
# Out:
# Warning message:
# “package ‘ggplot2’ was built under R version 4.0.2”

# %%
df1 <- data.frame(year = strrep(c("2018"), seq(1,1, length.out=6)), passengers = passng2018)

# %%
df2 <- data.frame(year = strrep(c("2019"), seq(1,1, length.out=6)), passengers = passng2019)

# %%
df3 <- data.frame(year = strrep(c("2020"), seq(1,1, length.out=6)), passengers = passng2020)

# %%
df_1819 <- rbind(df1, df2)

# %%
df <- rbind(df1, df2, df3)

# %%
p <- ggplot(df_1819, aes(x=year, y=passengers, fill=year)) + # fill=name allow to automatically dedicate a color for each group
  geom_violin()

# %%
p
# Out:
# plot without title

# %%
p <- ggplot(df3, aes(x=year, y=passengers, fill=year)) + # fill=name allow to automatically dedicate a color for each group
  geom_violin()

# %%
p
# Out:
# plot without title

# %%
p <- ggplot(df, aes(x=year, y=passengers, fill=year)) + # fill=name allow to automatically dedicate a color for each group
  geom_violin()

# %%
p
# Out:
# plot without title

# %% [markdown]
# Finally, to show the impact the covid-19 has had in the movement of people, we show a bar plot of our data

# %%
df$month = c(seq(1, 6, by=1), seq(1, 6, by=1), seq(1, 6, by=1))

# %%
p = ggplot(df, aes(x=month, y=passengers, fill=year)) + 
  geom_bar(stat="identity", width = .5, position=position_dodge())

# %%
p
# Out:
# plot without title
